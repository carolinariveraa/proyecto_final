# %% [markdown]
# # Sacando festivos nacionales desde 2014 hasta 2023

# %% [markdown]
# ### función y librerias

# %%
import datetime
import pandas as pd

# %% [markdown]
# 2014

# %%
festivos2014 = [
    "2014-01-01",
    "2014-01-06",
    "2014-04-18",
    "2014-05-01",
    "2014-08-15",
    "2014-10-12",
    "2014-11-01",
    "2014-12-06",
    "2014-12-08",
    "2014-12-25"
]

# %% [markdown]
# 2015

# %%
festivos2015 = [
    "2015-01-01",
    "2015-01-06",
    "2015-04-03",
    "2015-05-01",
    "2015-08-15",
    "2015-10-12",
    "2015-11-01",
    "2015-12-06",
    "2015-12-08",
    "2015-12-25"
]

# %% [markdown]
# 2016

# %%
festivos2016 = [
    "2016-01-01",
    "2016-01-06",
    "2016-03-25",
    "2016-05-01",
    "2016-08-15",
    "2016-10-12",
    "2016-11-01",
    "2016-12-06",
    "2016-12-08",
    "2016-12-25"
]

# %% [markdown]
# 2017

# %%
festivos2017 = [
    "2017-01-01",
    "2017-01-06",
    "2017-04-14",
    "2017-05-01",
    "2017-08-15",
    "2017-10-12",
    "2017-11-01",
    "2017-12-06",
    "2017-12-08",
    "2017-12-25"
]

# %% [markdown]
# 2018

# %%
festivos2018 = [
    "2018-01-01",
    "2018-01-06",
    "2018-03-30",
    "2018-05-01",
    "2018-08-15",
    "2018-10-12",
    "2018-11-01",
    "2018-12-06",
    "2018-12-08",
    "2018-12-25"
]

# %% [markdown]
# 2019

# %%
festivos2019 = [
    "2019-01-01",
    "2019-04-19",
    "2019-05-01",
    "2019-08-15",
    "2019-10-12",
    "2019-11-01",
    "2019-12-06",
    "2019-12-25"
]

# %% [markdown]
# 2020

# %%
festivos2020 = [
    "2020-01-01",
    "2020-01-06",
    "2020-04-10",
    "2020-05-01",
    "2020-08-15",
    "2020-10-12",
    "2020-12-08",
    "2020-12-25"
]

# %% [markdown]
# 2021

# %%
festivos2021 = [
    "2021-01-01",
    "2021-01-06",
    "2021-04-02",
    "2021-05-01",
    "2021-10-12",
    "2021-11-01",
    "2021-12-06",
    "2021-12-08",
    "2021-12-25"
]

# %% [markdown]
# 2022

# %%
festivos2022 = [
    "2022-01-01",
    "2022-01-06",
    "2022-04-15",
    "2022-08-15",
    "2022-10-12",
    "2022-11-01",
    "2022-12-06",
    "2022-12-08"
]

# %% [markdown]
# 2023

# %%
festivos2023 = [
    "2023-01-06",
    "2023-04-07",
    "2023-05-01",
    "2023-08-15",
    "2023-10-12",
    "2023-11-01",
    "2023-12-06",
    "2023-12-08",
    "2023-12-25"
]

# %%
festivos_total = festivos2014 + festivos2015 + festivos2016 + festivos2017 + festivos2018 + festivos2019 + festivos2020 + festivos2021 + festivos2022 + festivos2023

festivos_total
# Out:
# ['2014-01-01',
#  '2014-01-06',
#  '2014-04-18',
#  '2014-05-01',
#  '2014-08-15',
#  '2014-10-12',
#  '2014-11-01',
#  '2014-12-06',
#  '2014-12-08',
#  '2014-12-25',
#  '2015-01-01',
#  '2015-01-06',
#  '2015-04-03',
#  '2015-05-01',
#  '2015-08-15',
#  '2015-10-12',
#  '2015-11-01',
#  '2015-12-06',
#  '2015-12-08',
#  '2015-12-25',
#  '2016-01-01',
#  '2016-01-06',
#  '2016-03-25',
#  '2016-05-01',
#  '2016-08-15',
#  '2016-10-12',
#  '2016-11-01',
#  '2016-12-06',
#  '2016-12-08',
#  '2016-12-25',
#  '2017-01-01',
#  '2017-01-06',
#  '2017-04-14',
#  '2017-05-01',
#  '2017-08-15',
#  '2017-10-12',
#  '2017-11-01',
#  '2017-12-06',
#  '2017-12-08',
#  '2017-12-25',
#  '2018-01-01',
#  '2018-01-06',
#  '2018-03-30',
#  '2018-05-01',
#  '2018-08-15',
#  '2018-10-12',
#  '2018-11-01',
#  '2018-12-06',
#  '2018-12-08',
#  '2018-12-25',
#  '2019-01-01',
#  '2019-04-19',
#  '2019-05-01',
#  '2019-08-15',
#  '2019-10-12',
#  '2019-11-01',
#  '2019-12-06',
#  '2019-12-25',
# ...
